# %% [markdown]
# # Introductory Geocoding and Mapping

# %% [markdown]
# Andrew Chong
#
# Adapted from Juan Shishido's tutorial at: http://people.ischool.berkeley.edu/~juanshishido/geocoding-workshop/intro-geocoding.html
#
# School of Information
#
# GSR, D-Lab

# %% [markdown]
# ## Imports

# %%
import json
import requests
import pandas as pd
import geopy
from pprint import pprint

# %% [markdown]
# ## Using the APIs

# %% [markdown]
# ### Photon API

# %%
def get_geocoded_object_photon(address):
    # URL
    url = 'http://photon.komoot.de/api/?q=' + address.replace(' ', '+')
    
    # Response
    response = requests.get(url)
    return json.loads(response.text)

get_geocoded_object_photon("1600 Amphitheatre Pkwy, Mountain View, CA")
# Out:
# {u'features': [{u'geometry': {u'coordinates': [-122.0850862, 37.4228139],
#     u'type': u'Point'},
#    u'properties': {u'city': u'Mountain View',
#     u'country': u'United States of America',
#     u'housenumber': u'1600',
#     u'name': u'Google Headquaters',
#     u'osm_id': 2192620021,
#     u'osm_key': u'office',
#     u'osm_type': u'N',
#     u'osm_value': u'commercial',
#     u'postcode': u'94043',
#     u'state': u'California',
#     u'street': u'Amphitheatre Parkway'},
#    u'type': u'Feature'}],
#  u'type': u'FeatureCollection'}

# %% [markdown]
# ### Geopy Module
#
# Read Geopy's Documentation: https://geopy.readthedocs.org/en/1.10.0/#.
#
# Get your Google API key at: https://developers.google.com/maps/documentation/geocoding/get-api-key#key

# %% [markdown]
# #### Test out response object

# %%
my_api_key = "AIzaSyAMxZlb9Q4TkIDdhFJvDZ5mEMbobszayDA"
google_geocoder = geopy.geocoders.GoogleV3(api_key=my_api_key)
arcgis_geocoder = geopy.geocoders.ArcGIS()

response = google_geocoder.geocode("1600 Amphitheatre Pkwy, Mountain View, CA", google_geocoder) 
type(response)
# Out:
# geopy.location.Location

# %% [markdown]
# #### Navigating the response object
#
# What is a Location type?
# Just try to see if object has .keys() method or can be navigated using an index.

# %%
# response.keys()

response[0]
response[1]
response[1][0]
response[1][1]
# Out:
# -122.0840084

# %%
#### Write function that only returns latitude & longitude

# %%
def get_coords_geopy(address, geocoder_instance):
    response = geocoder_instance.geocode(address) 
    lat_lon = response[1][0], response[1][1]
    return lat_lon

coords = get_coords_geopy("1600 Amphitheatre Pkwy, Mountain View, CA", google_geocoder)
coords
# Out:
# (37.422245, -122.0840084)

# %% [markdown]
# ## Looping through a list of addresses from a text file

# %% [markdown]
# ### Load csv data into pandas DataFrame.

# %%
bart = pd.read_csv("data/bartstations.csv")
type(bart)
bart.keys()
# Out:
# Index([u'address', u'station_name'], dtype='object')

# %% [markdown]
# ### Quick Dip into Pandas
#
# Pandas in 10 minutes: http://pandas.pydata.org/pandas-docs/stable/10min.html

# %%
bart['weekday_visitors'] = 1000*bart.index
bart['weekend_visitors'] = 2000*bart.index
bart['weekly_visitors'] = bart['weekday_visitors'] + bart['weekend_visitors']

# %% [markdown]
# ### Apply upper function to each address using .apply()

# %%
one_address = "1245 Broadway, Oakland, CA 94612"
one_address_caps = one_address.upper()

bart['address_in_CAPS'] = bart['address'].apply(lambda x: x.upper())
bart
# Out:
#                                               address  \
# 0                    1245 Broadway, Oakland, CA 94612
# 1        2000 Mission Street, San Francisco, CA 94110
# 2                    1900 Broadway, Oakland, CA 94612
# 3        2800 Mission Street, San Francisco, CA 94110
# 4             3100 Adeline Street, Berkeley, CA 94703
# 5          401 Geneva Avenue, San Francisco, CA 94112
# 6        15242 Hesperian Blvd., San Leandro, CA 94578
# 7         3301 Norbridge Dr., Castro Valley, CA 94546
# 8         1150 Market Street, San Francisco, CA 94102
# 9             7200 San Leandro St., Oakland, CA 94621
# 10                      365 D Street, Colma, CA 94014
# 11             1451 Oakland Avenue, Concord, CA 94520
# 12           500 John Daly Blvd., Daly City, CA 94014
# 13           2160 Shattuck Avenue, Berkeley, CA 94704
# 14               5801 Owens Dr., Pleasanton, CA 94588
# 15           6400 Cutting Blvd., El Cerrito, CA 94530
# 16        6699 Fairmount Avenue, El Cerrito, CA 94530
# 17         298 Market Street, San Francisco, CA 94111
# 18                   2000 BART Way, Fremont, CA 94536
# 19           3401 East 12th Street, Oakland, CA 94601
# 20       2901 Diamond Street, San Francisco, CA 94131
# 21                    699 B Street, Hayward, CA 94541
# 22           3601 Deer Hill Road, Lafayette, CA 94549
# 23              800 Madison Street, Oakland, CA 94607
# 24                 555 40th Street, Oakland, CA 94609
# 25         200 North Rollins Road, Millbrae, CA 94030
# 26         598 Market Street, San Francisco, CA 94104
# 27         1750 Sacramento Street, Berkeley, CA 94702
# 28       3700 Port Chicago Highway, Concord, CA 94520
# 29                 4 Airport Drive, Oakland, CA 94621
# 30                  11 Camino Pablo, Orinda, CA 94563
# 31         1700 West Leland Road, Pittsburg, CA 94565
# 32           1365 Treat Blvd., Walnut Creek, CA 94597
# 33         899 Market Street, San Francisco, CA 94102
# 34              1700 Nevin Avenue, Richmond, CA 94801
# 35             5660 College Avenue, Oakland, CA 94618
# 36        1151 Huntington Avenue, San Bruno, CA 94066
# 37  International Terminal, Level 3, San Francisco...
# 38      1401 San Leandro Blvd., San Leandro, CA 94577
# 39              28601 Dixon Street, Hayward, CA 94544
# 40   1333 Mission Road, South San Francisco, CA 94080
# 41              10 Union Square, Union City, CA 94587
# 42    200 Ygnacio Valley Road, Walnut Creek, CA 94596
# 43           6501 Golden Gate Drive, Dublin, CA 94568
# 44                 1451 7th Street, Oakland, CA 94607
#
#                          station_name  weekday_visitors  weekend_visitors  \
# 0        12th St. Oakland City Center                 0                 0
# 1               16th St. Mission (SF)              1000              2000
# 2                    19th St. Oakland              2000              4000
# 3               24th St. Mission (SF)              3000              6000
# 4                    Ashby (Berkeley)              4000              8000
# 5                    Balboa Park (SF)              5000             10000
# 6              Bay Fair (San Leandro)              6000             12000
# 7                       Castro Valley              7000             14000
# 8          Civic Center/UN Plaza (SF)              8000             16000
# 9                            Coliseum              9000             18000
# 10                              Colma             10000             20000
# 11                            Concord             11000             22000
# 12                          Daly City             12000             24000
# 13                  Downtown Berkeley             13000             26000
# 14                  Dublin/Pleasanton             14000             28000
# 15               El Cerrito del Norte             15000             30000
# 16                   El Cerrito Plaza             16000             32000
# 17                   Embarcadero (SF)             17000             34000
# 18                            Fremont             18000             36000
# 19                Fruitvale (Oakland)             19000             38000
# 20                     Glen Park (SF)             20000             40000
# 21                            Hayward             21000             42000
# 22                          Lafayette             22000             44000
# 23             Lake Merritt (Oakland)             23000             46000
# 24                MacArthur (Oakland)             24000             48000
# 25                           Millbrae             25000             50000
# 26                Montgomery St. (SF)             26000             52000
# 27                     North Berkeley             27000             54000
# 28             North Concord/Martinez             28000             56000
# 29              Oakland Int'l Airport             29000             58000
# 30                             Orinda             30000             60000
# 31                Pittsburg/Bay Point             31000             62000
# 32  Pleasant Hill/Contra Costa Centre             32000             64000
# 33                    Powell St. (SF)             33000             66000
# 34                           Richmond             34000             68000
# 43           129000           6501 GOLDEN GATE DRIVE, DUBLIN, CA 94568
# 44           132000                 1451 7TH STREET, OAKLAND, CA 94607

# %% [markdown]
# ### Pass addresses through get_coords_geopy function

# %%
google_geocoder = geopy.geocoders.GoogleV3(api_key=my_api_key)
bart['latitude'], bart['longitude'] = zip(*bart['address'].apply(lambda x: get_coords_geopy(x, google_geocoder)))

bart[['station_name', 'latitude', 'longitude']]
# Out:
#                          station_name   latitude   longitude
# 0        12th St. Oakland City Center  37.803390 -122.271796
# 1               16th St. Mission (SF)  37.764789 -122.419959
# 2                    19th St. Oakland  37.807820 -122.268666
# 3               24th St. Mission (SF)  37.751992 -122.418722
# 4                    Ashby (Berkeley)  37.852883 -122.269977
# 5                    Balboa Park (SF)  37.721500 -122.447492
# 6              Bay Fair (San Leandro)  37.696980 -122.126499
# 7                       Castro Valley  37.691770 -122.074886
# 8          Civic Center/UN Plaza (SF)  37.780096 -122.412686
# 9                            Coliseum  37.753416 -122.196808
# 10                              Colma  37.684516 -122.466346
# 11                            Concord  37.974199 -122.030293
# 12                          Daly City  37.706131 -122.468900
# 13                  Downtown Berkeley  37.870059 -122.268054
# 14                  Dublin/Pleasanton  37.700654 -121.896780
# 15               El Cerrito del Norte  37.925167 -122.316882
# 16                   El Cerrito Plaza  37.902632 -122.298860
# 17                   Embarcadero (SF)  37.792879 -122.397087
# 18                            Fremont  37.557385 -121.976762
# 19                Fruitvale (Oakland)  37.775113 -122.224186
# 20                     Glen Park (SF)  37.733099 -122.434037
# 21                            Hayward  37.669840 -122.087077
# 22                          Lafayette  37.894699 -122.124125
# 23             Lake Merritt (Oakland)  37.797330 -122.265241
# 24                MacArthur (Oakland)  37.829155 -122.267037
# 25                           Millbrae  37.600377 -122.387500
# 26                Montgomery St. (SF)  37.789131 -122.401935
# 27                     North Berkeley  37.873967 -122.283399
# 28             North Concord/Martinez  38.003108 -122.024333
# 29              Oakland Int'l Airport  37.711946 -122.212065
# 30                             Orinda  37.878401 -122.183760
# 31                Pittsburg/Bay Point  38.015514 -121.945624
# 32  Pleasant Hill/Contra Costa Centre  37.928477 -122.055928
# 33                    Powell St. (SF)  37.784999 -122.406863
# 34                           Richmond  37.936816 -122.353059
# 35                Rockridge (Oakland)  37.844770 -122.251206
# 36                          San Bruno  37.637782 -122.416308
# 37        San Francisco Int'l Airport  37.623908 -122.381592
# 38                        San Leandro  37.722142 -122.160978
# 39                      South Hayward  37.634350 -122.057190
# 40                South San Francisco  37.663982 -122.443573
# 41                         Union City  37.590736 -122.017256
# 42                       Walnut Creek  37.905463 -122.067564
# 43             West Dublin/Pleasanton  37.700835 -121.927771
# 44                       West Oakland  37.804896 -122.295178

# %% [markdown]
# ## Map your geocoded addresses!

# %% [markdown]
# ### GeoJSON

# %%
geo_data = {
    'type': 'FeatureCollection', 
    'features': []
}

for i in bart.index:
    feature = {
        'type': 'Feature', 
        'geometry': {
            "type": "Point", 
            "coordinates": [float(bart['longitude'][i]), float(bart['latitude'][i])]
        },
            'properties': {
                'station_name': bart['station_name'][i]
            }
    }

    # Add the feature into the GeoJSON wrapper
    geo_data['features'].append(feature)

with open('map/geojson/bart_coords.geojson', 'wb') as f:
    json.dump(geo_data, f, indent=2)

# %%
with open('map/geojson/bart_coords.geojson', 'rb') as infile:
    lines = infile.readlines()

    with open('map/geojson/bart_coords.js', 'wb') as outfile:
        outfile.write('var bart = ')
        outfile.writelines(lines)

infile.close()
outfile.close()
